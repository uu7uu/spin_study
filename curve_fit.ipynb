# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np
 
def fund(x, a, b):
    return a*x**b
    #0.617,0.647,
#0.640,0.650,
#7.592,7.8765,
t1 = [0.780,0.755,0.739,0.733]
t2 = [0.784,0.756,0.739,0.733]
F = [7.5952,7.8765,8.9044,7.7538,6.8927,6.5014]
L = F[2:6]
print(L)

#plt.scatter(t1,L,color='b')
plt.scatter(t2,L,color='k',marker='x')
#y = fund(x1, 2.5, 1.3)

# plt.plot(t1,L,'b-')
popt, pcov = curve_fit(fund, t2, L, maxfev=5000)
# #popt数组中，三个值分别是待求参数a,b,c
y2 = [fund(i, popt[0],popt[1]) for i in t1]
plt.plot(t2,y2,'r--')

bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
ax.spines['bottom'].set_linewidth(bwith)
ax.spines['left'].set_linewidth(bwith)
ax.spines['top'].set_linewidth(bwith)
ax.spines['right'].set_linewidth(bwith)
plt.xticks(fontsize=20)
plt.yticks(fontsize=18)
plt.xlabel(r"$\mathrm{T_{in}}$",fontsize=24)
plt.ylabel(r"$\mathrm{Flux(10^{-8}\ erg\ cm^{-2}\ s^{-1})}$",fontsize=24)


#table4 画图
print(popt)
# Out:
# [8.9044, 7.7538, 6.8927, 6.5014]
# [26.87782786  4.51242505]

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np
 
def fund(x, a, b):
    return a*x**b
    #0.617,0.647,
#0.640,0.650,
#7.592,7.8765,
t1 = [0.780,0.755,0.739,0.733]
t2 = [0.784,0.756,0.739,0.733]

plt.scatter(t1,L,color='k',marker='x')
#plt.scatter(t2,L,color='k')
#y = fund(x1, 2.5, 1.3)

# plt.plot(t1,L,'b-')
popt, pcov = curve_fit(fund, t1, L, maxfev=5000)
# #popt数组中，三个值分别是待求参数a,b,c
y1 = [fund(i, popt[0],popt[1]) for i in t1]
plt.plot(t1,y1,'r--')
bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
ax.spines['bottom'].set_linewidth(bwith)
ax.spines['left'].set_linewidth(bwith)
ax.spines['top'].set_linewidth(bwith)
ax.spines['right'].set_linewidth(bwith)
plt.xticks(fontsize=20)
plt.yticks(fontsize=18)
plt.xlabel(r"$\mathrm{T_{in}}$",fontsize=24)
plt.ylabel(r"$\mathrm{Flux(10^{-8}\ erg\ cm^{-2}\ s^{-1})}$",fontsize=24)


print(popt)
# Out:
# [30.39217037  4.91740229]

# %%
tt1 = [0.617,0.647,0.780,0.755,0.739,0.733]
tt2 = [0.640,0.650,0.784,0.756,0.739,0.733]


plt.scatter(tt1,F,color='b',alpha=0.6,marker='x')
plt.scatter(tt2,F,color='r',alpha=0.5,marker='x')

plt.plot(t1,y1,'b--',label='4.917')
plt.plot(t2,y2,'r--',label='4.512')

bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
ax.spines['bottom'].set_linewidth(bwith)
ax.spines['left'].set_linewidth(bwith)
ax.spines['top'].set_linewidth(bwith)
ax.spines['right'].set_linewidth(bwith)
plt.xticks([0.63,0.66,0.69,0.72,0.75,0.78],fontsize=20)
plt.yticks(fontsize=18)
plt.xlabel(r"$k\mathrm{T_{in}(keV)}$",fontsize=24)
plt.ylabel(r"$\mathrm{Flux(10^{-8}\ erg\ cm^{-2}\ s^{-1})}$",fontsize=22)
plt.legend()

plt.savefig("LT.png", dpi=200, bbox_inches='tight')
